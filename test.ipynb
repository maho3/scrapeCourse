# %%
import requests
import smtplib
from time import sleep

# %%
[
    ('ECE','340','56895'),
    ('CS','498','65685')
]

# %%
def alert(address, course):
    ADDR = "matthew.annam.ho@gmail.com"
    passw = "pass11Word!"

    content = (course[0] + ' ' + course[1] + ', CRN: ' + course[2] + ', is available')
    
    mail = smtplib.SMTP('smtp.gmail.com',587)
    mail.ehlo()
    mail.starttls()
    mail.login(ADDR,passw)
    mail.sendmail(ADDR,address,content) 
    mail.close()
    print("Sent " + content[0])
    sleep(60*10)

# %%
while True:
    a = requests.get('http://courses.illinois.edu/cisapp/explorer/schedule/2017/spring/ECE/340/56895.xml', auth=()).text
    if u'Closed' in a:
        print('closed')
    else:
        print('OPEN: 56895')
        alert()
    sleep(60*5)

# %%
r = requests.get('https://courses.illinois.edu/schedule/2017/spring/CS/498')
type(r.text)
# Out:
# unicode

# %%
page = BeautifulSoup(r.text)
print(page)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Course Explorer</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!--<meta http-equiv="X-UA-Compatible" content="IE=edge">-->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/static/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- PROD -->
# <link href="/static/css/cis/cis.min.css" rel="stylesheet"/>
# <!--[if lte IE 9]>
#     <script src="/static/bootstrap/common/html5shiv.min.js"></script>
#     <script src="/static/bootstrap/common/respond.js"></script>
#  <![endif]-->
# <script src="/static/js/cis.min.js"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-52702852-2', 'auto');
#   ga('send', 'pageview');
#
# </script>
# </head>
# <body>
# <noscript><div id="noscript-padding"></div></noscript>
# <div id="wrap">
# <div role="banner">
# <div id="header-wrap">
# <div class="container" id="header-container">
# <div class="row">
# <div class="span12 hidden-xs" id="header">
# <a href="http://illinois.edu/" id="header-title" target="_blank">University of Illinois at Urbana-Champaign</a>
# <ul class="list-unstyled list-inline pull-right" id="login-info">
# <li><b>Hello Guest</b></li>
# <li><a href="https://illinois.edu/fb/sec/2080949">Contact Us</a></li>
# <li>
# <a href="/login">Login</a>
# </li>
# </ul>
# </div>
# <div class="span12 visible-xs-block" id="header-mobile">
# <a href="http://illinois.edu/" id="header-title" target="_blank">University of Illinois at Urbana-Champaign</a>
# <br/>
# <ul class="list-unstyled list-inline" id="login-info">
# <li><b>Hello Guest</b></li>
# <li><a href="https://illinois.edu/fb/sec/2080949">Contact Us</a></li>
# <li>
# <a href="/login">Login</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden-xs" id="header-brand-wrap">
# <div class="container">
# <div class="row">
# <div class="col-xs-6" id="header-brand">
# <a href="http://illinois.edu" target="_blank">
# <img alt="Illinois logo" src="/static/images/siteid-iblock.png"/>
# </a>
# <a class="noxs" href="/" id="header-brand-title">Course Explorer</a>
# </div>
# <div class="col-xs-6 easy-autocomplete" id="header-brand" style="padding-top: 15px;">
# <form action="/schedule/subjectjump" class="form-inline pull-right" id="subjectAutoJump-form" method="post">
# <div class="form-group">
# <label class="sr-only" for="subjectAutoJump" id="cb1-label">Enter and go to subject for the enrolling term</label>
# <input aria-autocomplete="list" aria-labelledby="cb1-label" aria-owns="subject-jump-list" aria-readonly="false" class="form-control" id="subjectAutoJump" name="subjectAutoJump" placeholder="Go to subject..." role="combobox"/>
# </div>
# <button class="btn btn-default" type="submit">Go!</button>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="visible-xs-block" id="header-brand-wrap-xs">
# <div class="container">
# <div class="row">
# <div class="span12" id="header-brand">
# <a href="/" id="header-brand-title-xs">Course Explorer</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div aria-label="primary" class="navbar navbar-default" id="app-main-nav" role="navigation">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".navbar-ex1-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse navbar-ex1-collapse">
# <ul class="nav navbar-nav nav-justified">
# <li><a href="/">Home</a></li>
# <li class="navbar-text">Schedule</li>
# <li><a href="/gened/DEFAULT/DEFAULT">GenEd REQs</a></li>
# <li><a href="/search/form">Search</a></li>
# <li><a href="/resources">Resources</a></li>
# </ul>
# </div>
# </div>
# <script type="text/javascript">
#     var sectionDataObj = [{"status":"<span class=\"hide\">1<\/span><span class=\"sr-only\">1. section open<\/span><img src=\"\/static\/images\/sectionOpen.png\" title=\"Open\" alt=\"Open\"\/>","crn":"61698","type":"<div class=\"app-meeting\">Laboratory<\/div>","section":"<div class=\"app-meeting\">AB1<\/div>","time":"<span class=\"hide\">0900<\/span><div class=\"app-meeting\">09:00AM - 10:50AM<\/div>","day":"<div class=\"app-meeting\">F      <\/div>","location":"<div class=\"app-meeting\">0222 Siebel Center for Comp Sci<\/div>","instructor":"<div class=\"app-meeting\">Campbell, R<br \/><\/div>","availability":"Open","credit":null,"sectionTitle":"Digital Forensics II","sectionDescription":null,"courseDescription":null,"sectionDegreeNotes":null,"courseDegreeNotes":null,"specialApproval":"","approvalCode":null,"sectionFee":"","sectionDateRange":null,"courseDateRange":null,"partOfTerm":"1","info":"This lab section will meet in 0222 Siebel Center","corequest":null,"restricted":""},{"status":"<span class=\"hide\">1<\/span><span class=\"sr-only\">1. section open<\/span><img src=\"\/static\/images\/sectionOpen.png\" title=\"Open\" alt=\"Open\"\/>","crn":"65904","type":"<div class=\"app-meeting\">Laboratory<\/div>","section":"<div class=\"app-meeting\">AB2<\/div>","time":"<span class=\"hide\">1100<\/span><div class=\"app-meeting\">11:00AM - 12:50PM<\/div>","day":"<div class=\"app-meeting\">F      <\/div>","location":"<div class=\"app-meeting\">0222 Siebel Center for Comp Sci<\/div>","instructor":"<div class=\"app-meeting\"><\/div>","availability":"Open","credit":null,"sectionTitle":"Digital Forensics II","sectionDescription":null,"courseDescription":null,"sectionDegreeNotes":null,"courseDegreeNotes":null,"specialApproval":"","approvalCode":null,"sectionFee":"","sectionDateRange":null,"courseDateRange":null,"partOfTerm":"1","info":null,"corequest":null,"restricted":""},{"status":"<span class=\"hide\">1<\/span><span class=\"sr-only\">1. section open<\/span><img src=\"\/static\/images\/sectionOpen.png\" title=\"Open\" alt=\"Open\"\/>","crn":"61697","type":"<div class=\"app-meeting\">Lecture<\/div>","section":"<div class=\"app-meeting\">AL1<\/div>","time":"<span class=\"hide\">0900<\/span><div class=\"app-meeting\">09:00AM - 09:50AM<\/div>","day":"<div class=\"app-meeting\">MW     <\/div>","location":"<div class=\"app-meeting\">1302 Siebel Center for Comp Sci<\/div>","instructor":"<div class=\"app-meeting\">Bambenek, J<br \/>Campbell, R<br \/><\/div>","availability":"Open","credit":"4 hours","sectionTitle":"Digital Forensics II","sectionDescription":null,"courseDescription":null,"sectionDegreeNotes":null,"courseDegreeNotes":null,"specialApproval":"","approvalCode":null,"sectionFee":"","sectionDateRange":null,"courseDateRange":null,"partOfTerm":"1","info":"This is a course for graduate students and advanced undergraduates wanting to develop greater depth and breadth in digital forensics and assumes a basic knowledge of the material covered in Digital Forensics I. Topics include standards of evidence, investigatory procedures, forms of investigation, legal procedures, reasoning about evidence, psychology of cyber crime, anti-forensics, multimedia forensics, computer forensics, web browser forensics, embedded systems forensics, network forensics, cloud forensics, applications forensics, and fraud examination. It introduces known barriers and open challenges in the field.    Prerequisite: Completion of Digital Forensics I or special permission granted by the instructor.","corequest":null,"restricted":""},{"status":"<span class=\"hide\">3<\/span><span class=\"sr-only\">section closed<\/span><img src=\"\/static\/images\/sectionClosed.png\" title=\"Closed\" alt=\"Closed\"\/>","crn":"65685","type":"<div class=\"app-meeting\">Lecture<\/div>","section":"<div class=\"app-meeting\">AML<\/div>","time":"<span class=\"hide\">1300<\/span><div class=\"app-meeting\">01:00PM - 02:15PM<\/div>","day":"<div class=\"app-meeting\">WF     <\/div>","location":"<div ...
#     var studentRole = false;
#     var showStatus = true;
#     //console.log(sectionDataObj);
# </script>
# <div id="app-content" role="main">
# <ul aria-label="breadcrumbs" class="breadcrumb app-breadcrumb" role="navigation">
# <li><a href="/schedule">schedule</a></li>
# <li><a href="/schedule/2017">2017</a></li>
# <li><a href="/schedule/2017/spring">spring</a></li>
# <li><a href="/schedule/2017/spring/CS">CS</a></li>
# <li class="active">498</li>
# </ul>
# <div class="row">
# <div class="col-sm-12">
# <div class="lead app-table-lead" style="margin-bottom:2px;">
# <div class="row">
# <div class="col-sm-12">
# <h1 class="app-inline">CS 498</h1>
# <div class="app-text-engage pull-right">
# <span class="app-cap">spring 2017</span>
# <div class="pull-right app-text-focus" style="font-size: 12px;line-height:13px;padding-left:10px;">
# <div> </div>
# <div>All Classes</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div app-label="course information" class="row" id="app-course-info">
# <div class="col-sm-12">
# <span class="app-label app-text-engage">Special Topics</span>
# <ul class="pull-right list-inline list-unstyled">
# <li><a href="http://catalog.illinois.edu/courses-of-instruction/cs" target="_BLANK">Course in Catalog</a></li>
# <li><a href="/schedule/terms/CS/498">List of Terms offered</a></li>
# <li>
# <a href="/pdf/schedule/2017/spring/CS/498">
#                                 PDF <img src="/static/images/pdf.png"/>
# </a>
# </li>
# <li>
# <a class="btn btn-xs app-btn-link" href="https://webprod.admin.uillinois.edu/ssa/servlet/SelfServiceLogin?appName=edu.uillinois.aits.SelfServiceLogin&amp;dad=BANPROD1&amp;target=A" style="padding:0 3px;" target="_BLANK">
#                                 Register for Classes
#                             </a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12">
# <p><b>Credit:</b> 1 to 4 hours.</p>
# <p>Subject offerings of new and developing areas of knowledge in computer science intended to augment the existing curriculum. See Class Schedule or departmental course information for topics and prerequisites. </p>
# <p>1 to 4 undergraduate hours. 1 to 4 graduate hours. May be repeated in the same or separate terms if topics vary.</p>
# </div>
# </div>
# <a aria-controls="toggle-info" aria-expanded="false" data-target="#toggle-info" data-toggle="collapse" href="#toggleinfo">
# <span aria-hidden="true" class="glyphicon glyphicon-info-sign"></span> Status Icon Legend
#             </a>
# <div class="collapse" id="toggle-info">
# <dl class="dl-horizontal">
# <dt><img alt="Closed" src="/static/images/sectionClosed.png"/></dt>
# <dd>Section Status Closed</dd>
# <dt><img alt="Open" src="/static/images/sectionOpen.png"/></dt>
# <dd>Section Status Open</dd>
# <dt><img alt="Pending" src="/static/images/sectionPending.png"/></dt>
# <dd>Section Status Pending</dd>
# <dt><img alt="Open (Restricted)" src="/static/images/sectionRestricted.png"/></dt>
# <dd>Section Status Open (Restricted)</dd>
# <dt><img alt="Unknown" src="/static/images/sectionUnknown.png"/></dt>
# <dd>Section Status Unknown</dd>
# </dl>
# </div>
# <div class="clearfix" style="border-bottom:1px solid #ccc;margin-bottom:2px;">
# <span class="app-text-focus" style="vertical-align:-5px;"><b>Section Status updates every 20 minutes.</b></span>
# <ul class="pull-right list-inline list-unstyled" style="margin-bottom:2px;">
# <li>
# <div aria-label="..." class="btn-group" role="group">
# <button class="btn app-btn-dflt btn-xs disabled" id="expandAllTR" type="button">Show Section Details</button>
# <button class="btn app-btn-dflt btn-xs" id="collapseAllTR" type="button">Hide Section Details</button>
# </div>
# </li>
# <li>
# <div class="btn-group">
# <button aria-expanded="false" class="btn app-btn-dflt btn-xs dropdown-toggle" data-toggle="dropdown" type="button">
#
#
#
#
#                                     CS - All Classes
#                                     <span class="caret"></span>
# </button>
# <ul class="dropdown-menu dropdown-menu-right" role="menu">
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/101" role="menuitem" tabindex="-1">
#                                                 CS 101
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/102" role="menuitem" tabindex="-1">
#                                                 CS 102
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/105" role="menuitem" tabindex="-1">
#                                                 CS 105
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/125" role="menuitem" tabindex="-1">
#                                                 CS 125
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/126" role="menuitem" tabindex="-1">
#                                                 CS 126
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/173" role="menuitem" tabindex="-1">
#                                                 CS 173
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/196" role="menuitem" tabindex="-1">
#                                                 CS 196
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/199" role="menuitem" tabindex="-1">
#                                                 CS 199
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/210" role="menuitem" tabindex="-1">
#                                                 CS 210
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/225" role="menuitem" tabindex="-1">
#                                                 CS 225
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/233" role="menuitem" tabindex="-1">
#                                                 CS 233
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/241" role="menuitem" tabindex="-1">
#                                                 CS 241
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/242" role="menuitem" tabindex="-1">
#                                                 CS 242
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/296" role="menuitem" tabindex="-1">
#                                                 CS 296
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/357" role="menuitem" tabindex="-1">
#                                                 CS 357
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/361" role="menuitem" tabindex="-1">
#                                                 CS 361
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/374" role="menuitem" tabindex="-1">
#                                                 CS 374
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/397" role="menuitem" tabindex="-1">
#                                                 CS 397
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/410" role="menuitem" tabindex="-1">
#                                                 CS 410
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/411" role="menuitem" tabindex="-1">
#                                                 CS 411
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/412" role="menuitem" tabindex="-1">
#                                                 CS 412
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/413" role="menuitem" tabindex="-1">
#                                                 CS 413
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/418" role="menuitem" tabindex="-1">
#                                                 CS 418
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/419" role="menuitem" tabindex="-1">
#                                                 CS 419
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/421" role="menuitem" tabindex="-1">
#                                                 CS 421
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/422" role="menuitem" tabindex="-1">
#                                                 CS 422
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/423" role="menuitem" tabindex="-1">
#                                                 CS 423
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/425" role="menuitem" tabindex="-1">
#                                                 CS 425
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/428" role="menuitem" tabindex="-1">
#                                                 CS 428
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/429" role="menuitem" tabindex="-1">
#                                                 CS 429
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/431" role="menuitem" tabindex="-1">
#                                                 CS 431
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/433" role="menuitem" tabindex="-1">
#                                                 CS 433
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/438" role="menuitem" tabindex="-1">
#                                                 CS 438
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/440" role="menuitem" tabindex="-1">
#                                                 CS 440
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/446" role="menuitem" tabindex="-1">
#                                                 CS 446
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/450" role="menuitem" tabindex="-1">
#                                                 CS 450
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/460" role="menuitem" tabindex="-1">
#                                                 CS 460
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/461" role="menuitem" tabindex="-1">
#                                                 CS 461
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/463" role="menuitem" tabindex="-1">
#                                                 CS 463
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/465" role="menuitem" tabindex="-1">
#                                                 CS 465
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/466" role="menuitem" tabindex="-1">
#                                                 CS 466
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/468" role="menuitem" tabindex="-1">
#                                                 CS 468
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/482" role="menuitem" tabindex="-1">
#                                                 CS 482
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/484" role="menuitem" tabindex="-1">
#                                                 CS 484
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/491" role="menuitem" tabindex="-1">
#                                                 CS 491
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/492" role="menuitem" tabindex="-1">
#                                                 CS 492
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/493" role="menuitem" tabindex="-1">
#                                                 CS 493
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/494" role="menuitem" tabindex="-1">
#                                                 CS 494
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/498" role="menuitem" tabindex="-1">
#                                                 CS 498
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/499" role="menuitem" tabindex="-1">
#                                                 CS 499
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/508" role="menuitem" tabindex="-1">
#                                                 CS 508
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/511" role="menuitem" tabindex="-1">
#                                                 CS 511
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/512" role="menuitem" tabindex="-1">
#                                                 CS 512
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/525" role="menuitem" tabindex="-1">
#                                                 CS 525
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/526" role="menuitem" tabindex="-1">
#                                                 CS 526
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/533" role="menuitem" tabindex="-1">
#                                                 CS 533
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/538" role="menuitem" tabindex="-1">
#                                                 CS 538
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/543" role="menuitem" tabindex="-1">
#                                                 CS 543
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/555" role="menuitem" tabindex="-1">
#                                                 CS 555
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/565" role="menuitem" tabindex="-1">
#                                                 CS 565
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/576" role="menuitem" tabindex="-1">
#                                                 CS 576
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/579" role="menuitem" tabindex="-1">
#                                                 CS 579
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/581" role="menuitem" tabindex="-1">
#                                                 CS 581
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/591" role="menuitem" tabindex="-1">
#                                                 CS 591
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/597" role="menuitem" tabindex="-1">
#                                                 CS 597
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/598" role="menuitem" tabindex="-1">
#                                                 CS 598
#                                             </a>
# </li>
# <li role="presentation">
# <a class="text-right" href="/schedule/2017/spring/CS/599" role="menuitem" tabindex="-1">
#                                                 CS 599
#                                             </a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <!--</div>-->
# <div class="panel panel-info" id="icon-help" style="display:none;">
# <div class="panel-heading">
# <a class="close app-toggle" data-target="icon-help" href="#" type="button">×</a>
# <b>STATUS ICON LEGEND</b>
# </div>
# <div class="panel-body">
# <p><img class="app-top" src="/static/images/sectionOpen.png"/>  <em class="text-muted">Section is Open</em></p>
# <p><img class="app-top" src="/static/images/sectionRestricted.png"/>  <em class="text-muted">Section is Open with Restrictions</em></p>
# <p><img class="app-top" src="/static/images/sectionClosed.png"/>  <em class="text-muted">Section is Closed</em></p>
# <p><img class="app-top" src="/static/images/sectionPending.png"/>  <em class="text-muted">Section is Pending</em></p>
# <p><img class="app-top" src="/static/images/sectionUnknown.png"/>  <em class="text-muted">Section is availability is unknown</em></p>
# </div>
# <div class="panel-footer">
# <button class="btn btn-default btn-xs app-toggle" data-target="icon-help" type="button">Close</button>
# </div>
# </div>
# <div class="table-responsive">
# <table class="table table-condensed" id="section-dt">
# <thead>
# <tr>
# <th>Detail</th>
# <th>Status</th>
# <th>CRN</th>
# <th>Type</th>
# <th>Section</th>
# <th>Time</th>
# <th>Day</th>
# <th>Location</th>
# <th>Instructor</th>
# </tr>
# </thead>
# <tbody></tbody>
# </table>
# </div>
# </div> <!-- end col-sm-12 -->
# </div> <!-- end row-fluid -->
# </div>
# </div>
# <div id="push"></div>
# </div>
# <footer id="footer" role="contentinfo">
# <div class="container">
# <div class="row">
# <div class="col-sm-1">
# <a class="pull-right" href="http://illinois.edu" target="_blank">
# <img alt="Illinois logo" src="/static/images/footer-imark.gif"/>
# </a>
# </div>
# <div class="col-sm-11">
# <p>
# <strong>
# <a href="http://registrar.illinois.edu/">OFFICE OF THE REGISTRAR</a>
# </strong> | 901 W. Illinois Street, Suite 140, Urbana, Illinois 61801</p>
# <p>
#                     Site developed by: <strong>
# <a href="http://techservices.illinois.edu/" target="_blank">Technology Services at Illinois</a>
# </strong>  |
#                     <a href="http://illinois.edu/" target="_blank">UNIVERSITY OF ILLINOIS AT URBANA-CHAMPAIGN</a>
# </p>
# <p>1102 Digital Computer Laboratory | MC-256 | Urbana, IL 61801
#                     | phone <a href="tel:2172447000">217-244-7000</a>
#                     | email <a href="https://illinois.edu/fb/sec/2080949">Course Explorer Feedback</a>
# </p>
# </div>
# </div>
# </div>
# </footer>
# <script src="/static/js/class-schedule.js"></script>
# <script src="/static/js/application.js"></script>
# <noscript>
# <div id="noscript-warning">Course Explorer works best with JavaScript enabled</div>
# </noscript>
# </body>
# </html>

# %%
m = re.search(r'(?<= \<script type="text/javascript"\>) \w+',str(r.text))
m.group(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-5de34db3d407> in <module>()
#       1 m = re.search(r'(?<= \<script type="text/javascript"\>) \w+',str(r.text))
# ----> 2 m.group(0)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
x = page.find('script',type='text/javascript')

# %%
import requests
import smtplib
from time import sleep
def alert():
    ADDR = 'DANK@NUGS.COM'
    content = ("340 (CRN 56895) is open")
    mail = smtplib.SMTP('smtp.gmail.com',587)
    mail.ehlo()
    mail.starttls()
    mail.login(ADDR,'EMAIL PASSWORD HERE')
    mail.sendmail(ADDR,ADDR,content) 
    mail.close()
    print("Sent")
    sleep(60*10)

while True:
    a = requests.get('http://courses.illinois.edu/cisapp/explorer/schedule/2017/spring/ECE/340/56895.xml', auth=()).text
    if u'Closed' in a:
        print('closed')
    else:
        print('OPEN: 56895')
        alert()
    sleep(60*5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-904040f3f26f> in <module>()
# ----> 1 json.loads(x.text)
#
# /usr/lib64/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# /usr/lib64/python2.7/json/decoder.pyc in decode(self, s, _w)
#     364
#     365         """
# --> 366         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     367         end = _w(s, end).end()
#     368         if end != len(s):
#
# /usr/lib64/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     382             obj, end = self.scan_once(s, idx)
#     383         except StopIteration:
# --> 384             raise ValueError("No JSON object could be decoded")
#     385         return obj, end
#
# ValueError: No JSON object could be decoded

# %%
import smtplib

# %%
a = requests.get('http://courses.illinois.edu/cisapp/explorer/schedule/2017/spring/ECE/340/56895.xml', auth=()).text

# %%
ADDR = 'matthew.annam.ho@gmail.com'
content = ("340 (CRN 56895) is open")
mail = smtplib.SMTP('smtp.gmail.com',587)
mail.ehlo()
mail.starttls()
mail.login(ADDR,'pass11Word!')
mail.sendmail(ADDR,ADDR,content) 
mail.close()
